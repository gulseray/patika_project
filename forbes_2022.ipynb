# %% [markdown]
# # Forbes 2022 billionaires

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
df = pd.read_csv("forbes_2022_billionaires.csv")

# %%
df.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# 2       Fashion & Retail                LVMH         France         NaN  ...
# 3             Technology           Microsoft  United States  Washington  ...
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska  ...
#
#                        organization selfMade gender   birthDate  \
# 0                             Tesla     True      M  1971-06-28
# 1                            Amazon     True      M  1964-01-12
# 2  LVMH Moët Hennessy Louis Vuitton    False      M  1949-03-05
# 3   Bill & Melinda Gates Foundation     True      M  1955-10-28
# 4                Berkshire Hathaway     True      M  1930-08-30
#
#               title philanthropyScore                 residenceMsa  \
# 0               CEO               1.0                          NaN
# 1      Entrepreneur               1.0  Seattle-Tacoma-Bellevue, WA
# 2  Chairman and CEO               NaN                          NaN
# 3         Cofounder               4.0  Seattle-Tacoma-Bellevue, WA
# 4               CEO               5.0                    Omaha, NE
#
#    numberOfSiblings                                                bio  \
# 0               NaN  Elon Musk is working to revolutionize transpor...
# 1               NaN  Jeff Bezos founded e-commerce giant Amazon in ...
# 2               NaN  Bernard Arnault oversees the LVMH empire of so...
# 3               NaN  Bill Gates turned his fortune from software fi...
# 4               NaN  Known as the "Oracle of Omaha," Warren Buffett...
#
#                                                about
# 0  Musk was accepted to a graduate program at Sta...
# 1  Growing up, Jeff Bezos worked summers on his g...
# 2  Arnault apparently wooed his wife, Helene Merc...
# 3  When Gates was a kid, he spent so much time re...
# 4  Buffett still lives in the same Omaha, Nebrask...
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#       rank               personName   age  finalWorth  year  month  \
# 2663  2578            Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578               Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578        Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578     Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578  Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#            category                   source country state  ... organization  \
# 2663  Manufacturing               Fiberglass   China   NaN  ...          NaN
# 2664     Technology               Navigation   China   NaN  ...          NaN
# 2665  Manufacturing                chemicals   China   NaN  ...          NaN
# 2666         Energy  liquefied petroleum gas   China   NaN  ...          NaN
# 2667  Manufacturing                polyester   China   NaN  ...          NaN
#
#      selfMade gender   birthDate title philanthropyScore residenceMsa  \
# 2663     True      M  1955-09-01   NaN               NaN          NaN
# 2664     True      M  1963-03-01   NaN               NaN          NaN
# 2665     True      M  1965-03-06   NaN               NaN          NaN
# 2666     True      F  1978-07-11   NaN               NaN          NaN
# 2667     True      M  1962-06-15   NaN               NaN          NaN
#
#       numberOfSiblings                                                bio  \
# 2663               NaN  Zhang Yuqiang chairs Zhenshi Holding Group, a ...
# 2664               NaN  Zhou Ruxin chairs Beijing BDStar Navigation, a...
# 2665               NaN  Zhou Wen chairs Shanghai Pret Composites, a su...
# 2666               NaN  Zhou Yifeng chairs Shenzhen-listed Oriental En...
# 2667               NaN  Zhuang Kuilong chairs Xinfengming Group, a man...
#
#       about
# 2663    NaN
# 2664    NaN
# 2665    NaN
# 2666    NaN
# 2667    NaN
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (2668, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  2668 non-null   int64
#  1   personName            2668 non-null   object
#  2   age                   2582 non-null   float64
#  3   finalWorth            2668 non-null   float64
#  4   year                  2668 non-null   int64
#  5   month                 2668 non-null   int64
#  6   category              2668 non-null   object
#  7   source                2668 non-null   object
#  8   country               2655 non-null   object
#  9   state                 748 non-null    object
#  10  city                  2624 non-null   object
#  11  countryOfCitizenship  2668 non-null   object
#  12  organization          352 non-null    object
#  13  selfMade              2668 non-null   bool
#  14  gender                2652 non-null   object
#  15  birthDate             2569 non-null   object
#  16  title                 401 non-null    object
#  17  philanthropyScore     396 non-null    float64
#  18  residenceMsa          639 non-null    object
#  19  numberOfSiblings      127 non-null    float64
#  20  bio                   2668 non-null   object
#  21  about                 1562 non-null   object
# dtypes: bool(1), float64(4), int64(3), object(14)
# memory usage: 440.4+ KB

# %%
df.columns
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
#        'about'],
#       dtype='object')

# %%
df = df.loc[:,["rank","personName","age","finalWorth","category","country","gender"]]
df.head()
# Out:
#    rank                personName   age  finalWorth               category  \
# 0     1                 Elon Musk  50.0    219000.0             Automotive
# 1     2                Jeff Bezos  58.0    171000.0             Technology
# 2     3  Bernard Arnault & family  73.0    158000.0       Fashion & Retail
# 3     4                Bill Gates  66.0    129000.0             Technology
# 4     5            Warren Buffett  91.0    118000.0  Finance & Investments
#
#          country gender
# 0  United States      M
# 1  United States      M
# 2         France      M
# 3  United States      M
# 4  United States      M

# %%
# rank sütununu veri setiindexi yaptık
df = df.set_index("rank")

# %%
df.head()
# Out:
#                     personName   age  finalWorth               category  \
# rank
# 1                    Elon Musk  50.0    219000.0             Automotive
# 2                   Jeff Bezos  58.0    171000.0             Technology
# 3     Bernard Arnault & family  73.0    158000.0       Fashion & Retail
# 4                   Bill Gates  66.0    129000.0             Technology
# 5               Warren Buffett  91.0    118000.0  Finance & Investments
#
#             country gender
# rank
# 1     United States      M
# 2     United States      M
# 3            France      M
# 4     United States      M
# 5     United States      M

# %%
df.dtypes
# Out:
# personName     object
# age           float64
# finalWorth    float64
# category       object
# country        object
# gender         object
# dtype: object

# %%
# bos degerler
df.isnull().sum()
# Out:
# personName     0
# age           86
# finalWorth     0
# category       0
# country       13
# gender        16
# dtype: int64

# %%
# bos degerleri silme
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (2568, 6)

# %%
df["category"].value_counts()
# Out:
# Finance & Investments         381
# Technology                    332
# Manufacturing                 319
# Fashion & Retail              238
# Healthcare                    209
# Food & Beverage               193
# Real Estate                   187
# Diversified                   174
# Media & Entertainment          95
# Energy                         93
# Automotive                     66
# Metals & Mining                65
# Service                        52
# Construction & Engineering     45
# Telecom                        37
# Logistics                      32
# Sports                         27
# Gambling & Casinos             23
# Name: category, dtype: int64

# %%
df["gender"].value_counts()
# Out:
# M    2282
# F     286
# Name: gender, dtype: int64

# %%
df["gender"].value_counts(normalize = True)
# Out:
# M    0.888629
# F    0.111371
# Name: gender, dtype: float64

# %%
df["country"].unique()
# Out:
# array(['United States', 'France', 'India', 'Mexico', 'China', 'Singapore',
#        'Spain', 'Canada', 'Germany', 'Switzerland', 'Belgium',
#        'Hong Kong', 'United Kingdom', 'Australia', 'Austria', 'Italy',
#        'Japan', 'Bahamas', 'Indonesia', 'Chile', 'Russia', 'Sweden',
#        'Czechia', 'Monaco', 'United Arab Emirates', 'Nigeria', 'Denmark',
#        'Thailand', 'Malaysia', 'Brazil', 'Colombia', 'New Zealand',
#        'South Korea', 'South Africa', 'Philippines', 'Egypt', 'Taiwan',
#        'Israel', 'Vietnam', 'Poland', 'Norway', 'Cayman Islands',
#        'Netherlands', 'Eswatini (Swaziland)', 'Peru', 'Algeria',
#        'Kazakhstan', 'Georgia', 'Portugal', 'British Virgin Islands',
#        'Turkey', 'Finland', 'Ukraine', 'Ireland', 'Bermuda', 'Lebanon',
#        'Argentina', 'Cambodia', 'Oman', 'Guernsey', 'Liechtenstein',
#        'Turks and Caicos Islands', 'Qatar', 'Morocco', 'Uruguay',
#        'Slovakia', 'Romania', 'Nepal', 'Tanzania', 'Bahrain', 'Greece',
#        'Hungary', 'Andorra'], dtype=object)

# %% [markdown]
# ### bazı ülkelerdeki kadın erkek milyarder oranları

# %%
df[df["country"]== "Turkey"].gender.value_counts(normalize = True)
# Out:
# M    0.826087
# F    0.173913
# Name: gender, dtype: float64

# %%
df[df["country"]== "United States"].gender.value_counts(normalize = True)
# Out:
# M    0.881402
# F    0.118598
# Name: gender, dtype: float64

# %%
df[df["country"]== "China"].gender.value_counts(normalize = True)
# Out:
# M    0.913919
# F    0.086081
# Name: gender, dtype: float64

# %%
df[df["country"]== "Egypt"].gender.value_counts(normalize = True)
# Out:
# M    1.0
# Name: gender, dtype: float64

# %%
df[df["country"]== "Sweden"].gender.value_counts(normalize = True)
# Out:
# M    0.8125
# F    0.1875
# Name: gender, dtype: float64

# %%
df[df["country"]== "Canada"].gender.value_counts(normalize = True)
# Out:
# M    0.952381
# F    0.047619
# Name: gender, dtype: float64

# %%
# cinsiyetlere göre gruplayarak yaş ortalamalarını alalım
df_gender = df.groupby(["gender"])
df_gender["age"].mean()
# Out:
# gender
# F    62.937063
# M    64.409290
# Name: age, dtype: float64

# %% [markdown]
# ### bazı kategorilerdeki kadın ve erkek oranları

# %%
df[df["category"]== "Finance & Investments"].gender.value_counts(normalize = True)
# Out:
# M    0.937008
# F    0.062992
# Name: gender, dtype: float64

# %%
df[df["category"]== "Technology"].gender.value_counts(normalize = True)
# Out:
# M    0.918675
# F    0.081325
# Name: gender, dtype: float64

# %%
df[df["category"]== "Healthcare"].gender.value_counts(normalize = True)
# Out:
# M    0.856459
# F    0.143541
# Name: gender, dtype: float64

# %% [markdown]
# ### veri görselleştirme

# %%
# Cinsiyet oranlarını hesapla
gender_counts = df["gender"].value_counts()

# Pasta grafiği oluştur
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.title("Milyarderlerin Cinsiyet Oranı")
plt.show()

# %%
# kadın ve erkeklerin sayılarına gore ortalama yaş grafiği
df_gender.size().plot(kind = "bar")
plt.title('Average ages of men and women', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Average ages of men and women')

# %%
# milyarderlerin cinsiyetlerine göre net değerlerinin analizi

# Erkek milyarderlerin ortalama net değeri
male_mean = df[df.gender == 'M']['finalWorth'].mean()

# Kadın milyarderlerin ortalama net değeri
female_mean = df[df.gender == 'F']['finalWorth'].mean()

# Cinsiyetlere göre verileri ayırma
male_data = df[df.gender == 'M']['finalWorth']   # erkeklerin finalworth değerlerini male_data değişkenine atadık
female_data = df[df.gender == 'F']['finalWorth'] # kadınların finalworth değerlerini male_data değişkenine atadık

# Kutu grafiği oluşturma
data = [male_data, female_data]
fig, ax = plt.subplots()
ax.boxplot(data)

# Grafiği özelleştirme
ax.set_xticklabels(['Erkek', 'Kadın'])
ax.set_ylabel('Net Değer')
ax.set_title('Cinsiyet Ücret Farkı Grafiği\nErkeklerin Ortalama Net Değeri: ${:,.2f}\nKadınların Ortalama Net Değeri: ${:,.2f}'.format(male_mean, female_mean))

# Grafiği gösterme
plt.show()

# %%
# cinsiyete göre net değerlerin dağılımı

# Random 10 ülke seçmek
countries = df['country'].unique().tolist()   # veri setindeki tüm ülkeleri bir listeye ekleme
selected_countries = random.sample(countries, k=10)  # listeden random 10 ülke seçip değişkene atama

# Seçilen ülkelerdeki erkek ve kadın milyarderlerin net değerlerini almak
male_net_worth = []
female_net_worth = []
for country in selected_countries:
    male_worth = df[(df['country'] == country) & (df['gender'] == 'M')]['finalWorth'].values
    female_worth = df[(df['country'] == country) & (df['gender'] == 'F')]['finalWorth'].values
    male_net_worth.extend(male_worth)
    female_net_worth.extend(female_worth)

# Verileri birleştirme
df_combined = pd.DataFrame({
    'Gender': ['Male']*len(male_net_worth) + ['Female']*len(female_net_worth),
    'Net Worth': male_net_worth + female_net_worth
})

# Grafik oluşturma
sns.violinplot(x='Gender', y='Net Worth', data=df_combined)
plt.title('Cinsiyete Göre Net Değerlerin Dağılımı (Seçilen 10 Ülkede)')
plt.show()

# %%
import plotly.express as px
import pycountry


# Standardize country names
def standardize_country(name):
    try:
        return pycountry.countries.lookup(name).name
    except:
        return name

df["country"] = df["country"].apply(standardize_country)

# Create a new DataFrame with just female billionaires
female_df = df[df["gender"] == "F"]

# Group by country and count the number of female billionaires in each country
counts_df = female_df.groupby("country")["personName"].count().reset_index()  # kadın milyarderleri atadık

# Rename the count column
counts_df.rename(columns={"personName": "count"}, inplace=True)

# dünya haritası
fig = px.choropleth(counts_df, locations="country", locationmode='country names', color="count", hover_name="country",
                    projection="natural earth", title="Distribution of Female Billionaires in 2022")
fig.show()
# Out:
# <div>                            <div id="17cfb55c-11b0-4dfe-8fbd-b318d4a52d80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17cfb55c-11b0-4dfe-8fbd-b318d4a52d80")) {                    Plotly.newPlot(                        "17cfb55c-11b0-4dfe-8fbd-b318d4a52d80",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>country=%{location}<br>count=%{z}<extra></extra>","hovertext":["Andorra","Australia","Austria","Bermuda","Brazil","Canada","Chile","China","Czechia","Denmark","Finland","France","Germany","Hong Kong","India","Indonesia","Israel","Italy","Japan","Kazakhstan","Korea, Republic of","Mexico","Monaco","Norway","Peru","Philippines","Poland","Portugal","Russia","Singapore","Spain","Sweden","Switzerland","Taiwan, Province of China","Turkey","United Kingdom","United States","Viet Nam"],"locationmode":"country names","locations":["Andorra","Australia","Austria","Bermuda","Brazil","Canada","Chile","China","Czechia","Denmark","Finland","France","Germany","Hong Kong","India","Indonesia","Israel","Italy","Japan","Kazakhstan","Korea, Republic of","Mexico","Monaco","Norway","Peru","Philippines","Poland","Portugal","Russia","Singapore","Spain","Sweden","Switzerland","Taiwan, Province of China","Turkey","United Kingdom","United States","Viet Nam"],"name":"","z":[1,9,2,2,7,2,2,47,1,2,1,4,19,10,11,1,4,15,1,1,5,1,1,2,1,4,1,1,1,1,6,6,12,2,4,7,88,1],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8 ...

# %%
female_df = df[df['gender'] == 'F']
plt.figure(figsize=(12,8))
sns.scatterplot(x='age', y='finalWorth', data=df, hue='category', palette='Spectral')
plt.xlabel('Age')
plt.ylabel('Final Worth (in billions)')
plt.title('Age vs. Final Worth of Female Billionaires by Category')
plt.show()

# %%
# rastgele seçilen 10 ülkede cinsiyet dağılımı çizgi grafiği
# Rastgele 10 ülke seçimi
random_countries = random.sample(list(df["country"].unique()), 10)

# Seçilen ülkelerdeki milyarderlerin cinsiyet dağılımını hesaplayın
country_gender_counts = []
for country in random_countries:
    billionaires = df[df["country"] == country]["personName"].count()
    male_count = df[(df["country"] == country) & (df["gender"] == "M")]["personName"].count()
    female_count = df[(df["country"] == country) & (df["gender"] == "F")]["personName"].count()
    male_percentage = (male_count / billionaires) * 100
    female_percentage = (female_count / billionaires) * 100
    country_gender_counts.append((country, male_percentage, female_percentage))
# x eksenindeki isimleri 45 derece döndürerek yazdır
plt.xticks(rotation=45)

# Çizgi grafiği oluşturma
df_country_gender_counts = pd.DataFrame(country_gender_counts, columns=["Country", "Male Percentage", "Female Percentage"])
df_country_gender_counts = df_country_gender_counts.melt(id_vars=["Country"], var_name="Gender", value_name="Percentage")
sns.lineplot(x="Country", y="Percentage", hue="Gender", data=df_country_gender_counts)
plt.title("Gender Distribution of Billionaires in Random 10 Countries (2022)")
plt.xlabel("Country")
plt.ylabel("Percentage")
plt.show()

# %%
# ülke göre cinsiyet dağılımını hesapla
gender_by_continent = df.groupby(["country", "gender"])["personName"].count().unstack()

# Kadın-erkek oranı grafiğini çizdir
fig, ax = plt.subplots(figsize=(20, 8))
gender_by_continent.plot(kind="bar", stacked=True, ax=ax)

# Eksen ve başlık ayarları
ax.set_xlabel("ülke")
ax.set_ylabel("Milyarder Sayısı")
ax.set_title("Ülkelere Göre Cinsiyet Dağılımı")

# X ekseni ayarları
ax.set_xlim(-0.4, len(gender_by_continent)-0.4)
ax.set_xticklabels(gender_by_continent.index, rotation=45, ha="right")

# Grafiği göster
plt.show()

# %%
# kıtalara göre kadın ve erkek oranları
continents = {
    'Asia': ['China', 'India', 'Hong Kong', 'Japan', 'South Korea', 'Taiwan'],
    'Europe': ['Austria', 'Belgium', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Ireland', 'Italy', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Russia', 'Spain', 'Sweden', 'Switzerland', 'Turkey', 'UK'],
    'North America': ['Canada', 'Mexico', 'USA'],
    'South America': ['Argentina', 'Brazil', 'Chile', 'Colombia', 'Peru'],
    'Africa': ['Egypt', 'Morocco', 'Nigeria', 'South Africa'],
    'Oceania': ['Australia']
}

def group_by_continent(country):
    for continent, countries in continents.items():
        if country in countries:
            return continent
    return None

df['continent'] = df['country'].apply(group_by_continent)

billionaire_counts = df['continent'].value_counts()

gender_counts = df.groupby('continent')['gender'].value_counts().unstack()

gender_ratios = gender_counts.divide(billionaire_counts, axis=0) * 100

ax = gender_ratios.plot(kind='bar', rot=0)

ax.set_title('Billionaires Gender Ratio by Continent (2022)', fontsize=14)
ax.set_xlabel('Continent', fontsize=12)
ax.set_ylabel('Gender Ratio (%)', fontsize=12)
ax.legend(fontsize=12)

plt.show()

# %%
# erkek ve kadınların yaşları histogram grafiği
plt.hist(df[df["gender"]=="M"]["age"], bins=20, alpha=0.5, label="Erkek")
plt.hist(df[df["gender"]=="F"]["age"], bins=20, alpha=0.5, label="Kadın")
plt.legend(loc='upper right')
plt.xlabel('Yaş')
plt.ylabel('Frekans')
plt.show()
